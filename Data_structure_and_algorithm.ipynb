# %% [markdown]
# <a href="https://colab.research.google.com/github/Manibharthi/python/blob/master/Data_structure_and_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Algorithm:**
# 1.**What is algorithm?**
# Set of rules and steps be framed and followed to solve a problems
#
# 2. **How to analyze algorithm?**
# We use two major factor to analyze, that is Time and space.
# **Time:** time to taken a outpur by solving a problem
# Time taken is based on machine architectuture, 32, 64 bites and based on execuion, basde on memory read and write operations, also based on input.
#
# **Data Structure:**
# Basic activity is store, search, modify
#
#
# **Space:** memory taken by algorithm to solve and storage space of problem steps
#
# **Time Complexity:**
# Ex:
# swap (a, b)
# a = temp  ------> operation 1  |
# a= b   ------> operation 2        |   ---> total (o)= o(3)
# b = temp ------> operation 3   |
# print(a, temp)
#
# The number of opeartions taken in the problems are called time complexity
#
# **Space complexity:**
# int i = 10 ------> it has one operatinon and one variable contains one value,.
#
# **Big (o) notation types:**
# **linear complexity:**
# o(1): it is Best type because it contains only one operation
# o(logn): operation will partially increase but not more, even with huge data
# 0(n): opeartion will increase based on the number of data
# o(n logn): its opeartion will partially increase when data is also normal
#
# **Exponential complexity**
# o(n^2): n^2 = (n is data) = 4**2 = 16operations. Number of opeartions is very high with less number of data
# o(2^n): 2 ^n = (n is data) = 2**4 = 16 operations
#
# **What is data structure?**
# storing and organizing data in structered way
#
# **Two types of data structure:**
# primitive: integer, real, character, boolean
# Non-primitive:Linear, non-linear
#
# **Linear**: data refers the previews data, which is data comes in sequence
# Types: Queue, linked-list, stack, Array
# Ex: ticket booking app
#
# **Non-linear**: unstructured data
# Types: Tree, graph
# Ex: map
#
# **Array**
#
# It stores infinte number of data inside the square bracket. it works based on the matrix rows and coloums
# Syntax to access the entire array in python is:
# x = [a, b, c,d,e]
# print(len(x)) => o/p= 5
# Syntax to access the specific value in array in python is:
# print(x[2])=> o/p= c
#
# **Issue in array is:**
# It is hard to insert a value in middle of the array, so possible way is to move the remain data from that target position using swap method.
# We can't store different types of data
#
# To change the value in array:
# #Array
# import array as arr
# x = ['a', 'b', 'c','d','e']
# print(len(x))
# print(x[2])
# #To change the value in array
# x[2] = ('h')
# print(x[2])
# for i in x:
#   print (i)
#
# #create an array
# import array as arr
# y = arr.array('i', [1, 2, 3,4, 5, 6])
# print(y)
#
#
# #sclicing:
# x = [1:4]
# print(x)
#
# #append to add new element
# append.
#
#
# **STACK**
#
# order data in one by one (ex: Browsers)
# LIFO: Last in First out
#      _last data
#     __
#    ___
#   ____first data
#
# We can take only the last data as output
# Methods:  pop, append, and insert, remove, clear, del
#
# append(Push): add
# pop: remove

# %% [markdown]
# Numpy
# it is used for linear algebra
# used to perform mathematical & logical operations in array
# it has various functions
#
# Create Numpy array
# 1D Array:
#
# import numpy as np
# a = np.array([1,3,2,4,5])
# print(a)
# print(type(a))
#
# 2D Array:
# import numpy as np
# b = np.array([[1,2,3],[4,5,6]])
# print(b)
# print(type(b))
#
# 3.initialize all the elements of x * y to 0
# np.zeros((3,4)) #zeros is inbuilt funciton for zero
#
# 4.arranging the numbers between x, y with an interval of z
# np.arange(1, 10, 2)
#
# 5.even numbers between 10, 20
# np.arange(10,20,2)
#
# 6.Arrange z numbers between x, y
# np.linspace(5, 10, 2)
#
# 7. filling same number in an array of dimension  x*y
# np.full((2,3),10)
#
# 8.filling some random number in an array of dimension of x*y
# np.random.random((2,3))
#
# 9. find the shape of the array and resize it
# s = np.array([[1,2,3],[4,5,6])
# print(s.shape)
#
# #resize the shape of the array
# d = np.array([[1,2,3],[4,5,6]]
# d.shape(3,4)
# print(d)

# %%
import numpy as np
#1D Array:
# a = np.array([1,3,2,4,5])
# print(a)
# print(type(a))

#2D Array:

# b = np.array([[1,2,3],[4,5,6]])
# print(b)
# print(type(b))

#initialize all the elements of x * y to 0
#np.zeros((3,4)) #zeros is inbuilt funciton for zero

#arranging the numbers between x, y with an interval of z
#np.arange(1, 10, 2)

#even numbers between 10, 20
#np.arange(10,20,2)

#Arrange z numbers between x, y
#np.linspace(5, 10, 10)

# filling same number in an array of dimension  x*y
#np.full((2,3),10)

#filling some random number in an array of dimension of x*y
#np.random.random((2,3))


#find the shape of the array and resize it
# s = np.array([[1,2,3],[4,5,6]])
# print(s.shape)
 
#resize the shape of the array
# d = np.array([[1,2,3],[4,5,6]])
# d.shape=(3,2)
# print(d)

#check the dimesnion of array
# a =np.arange(24)
# a
#print(a.ndim)
#reshape the array
#z=a.reshape(2,4, 3)
#print(z.ndim)
# Out:
# 1
# 3

# %%
#Array
import array as arr
x = ['a', 'b', 'c','d','e']
# print(len(x))
# print(x[2])
# #To change the value in array
# x[2] = ('h')
# print(x[2])
# for i in x:
#   print (i)

#slicing
#y = arr.array('i', [1, 2, 3,4, 5, 6])
# print(y[1:4])
print(x.append('t'))
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4792ca9d0f7f> in <module>()
#      13 #y = arr.array('i', [1, 2, 3,4, 5, 6])
#      14 # print(y[1:4])
# ---> 15 print(x.pop('t'))
#      16 print(x)
#      17
#
# TypeError: 'str' object cannot be interpreted as an integer
